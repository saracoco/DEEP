# %%
Notebook just to keep track of the steps to implement UNet

# %% [markdown]
# ![image.png](attachment:image.png)
#
# https://www.sciencedirect.com/science/article/pii/S0952197624009096

# %%
srun -n1 -N1 -p THIN --time=10:0:0 --mem=900g --pty bash

module load conda  #somethines already loaded, understand why
conda activate r_env

# %%
python3 prepare_data_and_model.py
sbatch Job_UNet_train.sh 
python3 visualize_Unet.py

# %%
sbatch Job_UNet2_train.sh 
python3 visualize_Unet2.py

# %%
sbatch Job_Attention_UNet_train.sh 
python3 visualize_Attention_UNet.py
python3 train_visualize_Attention_UNet.py
